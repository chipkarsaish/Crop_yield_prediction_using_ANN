# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Target Variable (Output Feature)
# ### Value:
#
# Data type (raw): Integer / Float
#
# ML type: Numerical (Continuous)
#
# Role: Target / Label
#
#
# 📌 Represents the amount of pesticide usage (in tonnes).
#
#
# ## Input Features (Independent Variables)
# ### Domain:
#
# Data type: String (Categorical)
#
#
# 📌 Describes the agricultural domain.
#
#
# ### Area
#
# Raw data type: String (Categorical)
#
#
#
# 📌 Represents geographical region or country.
#
#
#
# ### Element
#
# Raw data type: String (Categorical)
#
#
# 📌 Defines what is being measured.
#
#
#
# ### Item
#
# Raw data type: String (Categorical)
#
#
#
# 📌 Specifies type of item used.
#
#
#
# ### Year
#
# Raw data type: Integer
#
#
# 📌 Represents time information.
#
#
#
# ### Unit
#
# Raw data type: String (Categorical)
#
#
#
# ML type: Categorical (Very low cardinality)
#
# 📌 Measurement unit.
#
# ⚠️ If unit is always the same → drop column
# ✅ Else → One-Hot Encoding
